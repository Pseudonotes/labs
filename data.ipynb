# %%
import pandas as pd

# %%
df=pd.read_csv('soils.csv')
filtered_frame = df[:100]
# .drop(columns=['the_geom','FID','LNDF','SDRA','TEXT','RSLO','CLAY','RDEP','PROP'])
# df.AREA
# filtered_frame.head(2)
filtered_frame.to_json('100soils.json', indent=4)
